# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tpy1.plotting import dist_box
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from tpy1.plotting import dist_box
#
# ModuleNotFoundError: No module named 'tpy1'
