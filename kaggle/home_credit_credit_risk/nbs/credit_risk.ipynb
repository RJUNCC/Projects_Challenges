# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import glob
import os

# %%
DATA_PATH ="../data/parquet_files/train/" 
data_files = os.listdir("../data/parquet_files/train")
data_files
# Out:
# ['train_applprev_1_0.parquet',
#  'train_applprev_1_1.parquet',
#  'train_applprev_2.parquet',
#  'train_base.parquet',
#  'train_credit_bureau_a_1_0.parquet',
#  'train_credit_bureau_a_1_1.parquet',
#  'train_credit_bureau_a_1_2.parquet',
#  'train_credit_bureau_a_1_3.parquet',
#  'train_credit_bureau_a_2_0.parquet',
#  'train_credit_bureau_a_2_1.parquet',
#  'train_credit_bureau_a_2_10.parquet',
#  'train_credit_bureau_a_2_2.parquet',
#  'train_credit_bureau_a_2_3.parquet',
#  'train_credit_bureau_a_2_4.parquet',
#  'train_credit_bureau_a_2_5.parquet',
#  'train_credit_bureau_a_2_6.parquet',
#  'train_credit_bureau_a_2_7.parquet',
#  'train_credit_bureau_a_2_8.parquet',
#  'train_credit_bureau_a_2_9.parquet',
#  'train_credit_bureau_b_1.parquet',
#  'train_credit_bureau_b_2.parquet',
#  'train_debitcard_1.parquet',
#  'train_deposit_1.parquet',
#  'train_other_1.parquet',
#  'train_person_1.parquet',
#  'train_person_2.parquet',
#  'train_static_0_0.parquet',
# ...

# %%
applprev_1= pd.read_parquet(DATA_PATH+data_files[0])
applprev_1.head()
# Out:
#    case_id  actualdpd_943P  ...  status_219L tenor_203L
# 0        2             0.0  ...            D       24.0
# 1        2             0.0  ...            D       12.0
# 2        3             0.0  ...            D       12.0
# 3        4             0.0  ...            T       24.0
# 4        5             0.0  ...            T        NaN
#
# [5 rows x 41 columns]

# %%
applprev_1.shape
# Out:
# (3887684, 41)

# %%
applprev_1_1 = pd.read_parquet(DATA_PATH+data_files[1])
applprev_1_1.head()
# Out:
#    case_id  actualdpd_943P  ...  status_219L tenor_203L
# 0    40704             0.0  ...            D       12.0
# 1    40734             0.0  ...            D       18.0
# 2    40737             0.0  ...            D       18.0
# 3    40791             0.0  ...            D       12.0
# 4    40791             0.0  ...            D       24.0
#
# [5 rows x 41 columns]

# %%
applprev_1_1.shape
# Out:
# (2638295, 41)

# %%
applprev_2 = pd.read_parquet(DATA_PATH+data_files[2])
applprev_2.head()
# Out:
#    case_id cacccardblochreas_147M  ... num_group1 num_group2
# 0        2                   None  ...          0          0
# 1        2                   None  ...          0          1
# 2        2                   None  ...          1          0
# 3        2                   None  ...          1          1
# 4        3                   None  ...          0          0
#
# [5 rows x 6 columns]
